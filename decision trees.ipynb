# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("HRAttrition.csv")
df.head(4)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
X=df.drop(['Attrition'],axis=1)
y=df['Attrition']

# %%
a=pd.get_dummies(X[['Department','Gender','BusinessTravel','EducationField','JobRole','MaritalStatus','Over18','OverTime']])
a.head()
# Out:
#    Department_Human Resources  Department_Research & Development  \
# 0                           0                                  0
# 1                           0                                  1
# 2                           0                                  1
# 3                           0                                  1
# 4                           0                                  1
#
#    Department_Sales  Gender_Female  Gender_Male  BusinessTravel_Non-Travel  \
# 0                 1              1            0                          0
# 1                 0              0            1                          0
# 2                 0              0            1                          0
# 3                 0              1            0                          0
# 4                 0              0            1                          0
#
#    BusinessTravel_Travel_Frequently  BusinessTravel_Travel_Rarely  \
# ...

# %%
b=X.drop(['Department','Gender','BusinessTravel','EducationField','JobRole','MaritalStatus','Over18','OverTime'],axis=1)
b.head(0)
# Out:
# Empty DataFrame
# Columns: [Age, DailyRate, DistanceFromHome, Education, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, HourlyRate, JobInvolvement, JobLevel, JobSatisfaction, MonthlyIncome, MonthlyRate, NumCompaniesWorked, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 26 columns]

# %%
x=pd.concat([a,b],axis=1)
x
# Out:
#       Department_Human Resources  Department_Research & Development  \
# 0                              0                                  0
# 1                              0                                  1
# 2                              0                                  1
# 3                              0                                  1
# 4                              0                                  1
# ...                          ...                                ...
# 1465                           0                                  1
# 1466                           0                                  1
# 1467                           0                                  1
# 1468                           0                                  0
# 1469                           0                                  1
#
#       Department_Sales  Gender_Female  Gender_Male  BusinessTravel_Non-Travel  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x, y, stratify=y, test_size= 0.15,random_state=1)

# %%
modelDecisionTreeEntropy = DecisionTreeClassifier(criterion='entropy', max_depth=4)
modelDecisionTreeEntropy.fit(x_train,y_train)
predDTEntropy = modelDecisionTreeEntropy.predict(x_test)
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test,predDTEntropy)
cnf_matrix
print("Accuracy Decision Tree Entropy:",metrics.accuracy_score(y_test, predDTEntropy))
# Out:
# Accuracy Decision Tree Entropy: 0.8823529411764706

# %%
modelDecisionTreeEntropy = DecisionTreeClassifier(criterion='entropy', max_depth=200,max_leaf_nodes=10,max_features=20)
modelDecisionTreeEntropy.fit(x_train,y_train)
predDTEntropy = modelDecisionTreeEntropy.predict(x_test)
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test,predDTEntropy)
cnf_matrix
print("Accuracy Decision Tree Entropy:",metrics.accuracy_score(y_test, predDTEntropy))
# Out:
# Accuracy Decision Tree Entropy: 0.8597285067873304

# %%
modelDecisionTreeEntropy = DecisionTreeClassifier(criterion='entropy', max_depth=200)
modelDecisionTreeEntropy.fit(x_train,y_train)
predDTEntropy = modelDecisionTreeEntropy.predict(x_test)
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test,predDTEntropy)
cnf_matrix
print("Accuracy Decision Tree Entropy:",metrics.accuracy_score(y_test, predDTEntropy))
# Out:
# Accuracy Decision Tree Entropy: 0.8280542986425339
